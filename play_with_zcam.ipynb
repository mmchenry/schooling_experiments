# %%
import requests


camera_ip = "10.98.32.1"

base_url = f"http://{camera_ip}"

# %%
def get_camera_status():
    url = f"{base_url}/ctrl/get"
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()  # Returns the camera status as a JSON object
    else:
        return None

status = get_camera_status()
if status:
    print(status)
# Out:
# {'code': -1, 'desc': 'Key is not supported', 'msg': ''}

# %%
response = requests.get(base_url)
print(response.status_code)
print(response.text)
# Out:
# 200
# <!doctype html>
# <html lang="en" translate="no">
# <head>
#     <meta charset="utf-8">
#     <meta name="google" content="notranslate">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <link rel="icon" href="data:;base64,=">
#     <title>Z CAM Controller</title>
#
#     <link rel="stylesheet" href="/www/css/jquery-ui.min.css">
#     <link rel="stylesheet" href="/www/css/jquery.switchButton.min.css">
#     <link rel="stylesheet" href="/www/css/controller.min.css">
#
#     <script src="/www/js/jquery-3.7.1.min.js"></script>
#     <script src="/www/js/jquery-ui.min.js"></script>
#     <script src="/www/js/jquery.md5.js"></script>
#     <script src="/www/js/jquery.timers.min.js"></script>
#     <script src="/www/js/adapter.min.js" ></script>
#     <script src="/www/js/webrtcstreamer.js" ></script>
#     <script src="/www/js/jquery.switchButton.js"></script>
#     <script src="/www/js/controller.js"></script>
# </head>
# ...

# %%
# import requests

def set_focus_to_af(camera_ip):
    url = f"http://{camera_ip}/ctrl/set?focus=MF"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        if data['code'] == 0:
            print("Focus set to AF successfully.")
        else:
            print(f"Failed to set focus to AF. Response: {data}")
    else:
        print(f"Error: {response.status_code}")

# camera_ip = "192.168.1.2"  # Replace with your camera's actual IP address
set_focus_to_af(camera_ip)
# Out:
# Focus set to AF successfully.

# %%
# import requests

def set_timecode_to_freerun(camera_ip):
    # url = f"http://{camera_ip}/ctrl/set?tc_count_up=free%20run"
    # url = f"http://{camera_ip}/ctrl/set?tc_count_up=free+run"
    url = f"http://{camera_ip}/ctrl/set?tc_count_up=Free%20Run"
    # url = f"http://{camera_ip}/ctrl/set?tc_count_up=Rec%20Run"
    # url = f"http://{camera_ip}/ctrl/set?max_iso=5000"
    # url = f"http://{camera_ip}/ctrl/set?tc_drop_frame=NDF"

    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        if data['code'] == 0:
            print("Timecode set to Free Run successfully.")
        else:
            print(f"Failed to set timecode to Free Run. Response: {data}")
    else:
        print(f"Error: {response.status_code}")

# camera_ip = "192.168.1.2"  # Replace with your camera's actual IP address
set_timecode_to_freerun(camera_ip)
# Out:
# Timecode set to Free Run successfully.

# %%
def set_timecode_to_freerun(camera_ip):
    # url = f"http://{camera_ip}/ctrl/set?tc_count_up=free%20run"
    # url = f"http://{camera_ip}/ctrl/set?tc_count_up=free+run"
    url = f"http://{camera_ip}/ctrl/set?tc_count_up=Rec%20Run"
    # url = f"http://{camera_ip}/ctrl/set?tc_count_up=Rec%20Run"
    # url = f"http://{camera_ip}/ctrl/set?max_iso=5000"
    # url = f"http://{camera_ip}/ctrl/set?tc_drop_frame=NDF"

    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        if data['code'] == 0:
            print("Timecode set to Free Run successfully.")
        else:
            print(f"Failed to set timecode to Free Run. Response: {data}")
    else:
        print(f"Error: {response.status_code}")

# camera_ip = "192.168.1.2"  # Replace with your camera's actual IP address
set_timecode_to_freerun(camera_ip)
# Out:
# Timecode set to Free Run successfully.

# %%
def set_timecode_to_freerun(camera_ip):

    url = f"http://{camera_ip}/ctrl/rec?action=start"

    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        if data['code'] == 0:
            print("Timecode set to Free Run successfully.")
        else:
            print(f"Failed to set timecode to Free Run. Response: {data}")
    else:
        print(f"Error: {response.status_code}")

# %%
# import requests

def start_camera_recording(camera_ip):
    url = f"http://{camera_ip}/ctrl/rec?action=start"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        if data['code'] == 0:
            print("Camera recording started successfully.")
        else:
            print(f"Failed to start camera recording. Response: {data}")
    else:
        print(f"Error: {response.status_code}")

# camera_ip = "192.168.1.2"  # Replace with your camera's actual IP address
start_camera_recording(camera_ip)
# Out:
# Camera recording started successfully.

# %%
# import requests

def stop_camera_recording(camera_ip):
    url = f"http://{camera_ip}/ctrl/rec?action=stop"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        if data['code'] == 0:
            print("Camera recording stopped successfully.")
        else:
            print(f"Failed to stop camera recording. Response: {data}")
    else:
        print(f"Error: {response.status_code}")

# camera_ip = "192.168.1.2"  # Replace with your camera's actual IP address
stop_camera_recording(camera_ip)
# Out:
# Camera recording stopped successfully.
